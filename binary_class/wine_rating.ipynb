# %% [markdown]
# # Wine Classification
#
# Author: Rafael Godoy
#
# LinkedIn: www.linkedin.com/in/Rafael-Godoy-ML-Eng
#
# Github: https://github.com/RafaelSilvaGodoy
#
#
# This notebook will show a **basic use of Neural Network** for **binary classification**.
#
# The wines will be classified as good if the note is superior of 5, otherwise bad.
#
#
# The dataset was provided by [Kaggle wine dataset](https://www.kaggle.com/uciml/red-wine-quality-cortez-et-al-2009).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

import random
# Set seed to 42 for reproducibility.
random.seed(42)

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('winequality-red.csv')
print(f'Dataset size: {df.shape}')
df.sample(4)
# Out:
# Dataset size: (1599, 12)
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1490            7.1              0.22         0.49             1.8      0.039
# 1543           11.1              0.44         0.42             2.2      0.064
# 387             8.3              0.66         0.15             1.9      0.079
# 466            10.3              0.50         0.42             2.0      0.069
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1490                  8.0                  18.0  0.99344  3.39       0.56
# 1543                 14.0                  19.0  0.99758  3.25       0.57
# 387                  17.0                  42.0  0.99720  3.31       0.54
# 466                  21.0                  51.0  0.99820  3.16       0.72
#
#       alcohol  quality
# 1490     12.4        6
# 1543     10.4        6
# 387       9.6        6
# 466      11.5        6

# %%
print(f'Number of missing values on the dataset: {df.isna().sum(axis=0).sum()}')

# The Correlation Matrix between the dataset variables shows us a glance of how the variables correlate with the 'Quality' column.
df.corr().style.background_gradient()
# Out:
# Number of missing values on the dataset: 0
# <style  type="text/css" >
# #T_26773_row0_col0,#T_26773_row1_col1,#T_26773_row2_col2,#T_26773_row3_col3,#T_26773_row4_col4,#T_26773_row5_col5,#T_26773_row6_col6,#T_26773_row7_col7,#T_26773_row8_col8,#T_26773_row9_col9,#T_26773_row10_col10,#T_26773_row11_col11{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_26773_row0_col1,#T_26773_row4_col11,#T_26773_row9_col1{
#             background-color:  #dedcec;
#             color:  #000000;
#         }#T_26773_row0_col2{
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }#T_26773_row0_col3,#T_26773_row4_col10{
#             background-color:  #dfddec;
#             color:  #000000;
#         }#T_26773_row0_col4{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_26773_row0_col5,#T_26773_row0_col8,#T_26773_row1_col2,#T_26773_row1_col9,#T_26773_row1_col11,#T_26773_row2_col1,#T_26773_row7_col10,#T_26773_row8_col0,#T_26773_row8_col3,#T_26773_row8_col4,#T_26773_row10_col6,#T_26773_row10_col7{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_26773_row0_col6{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_26773_row0_col7{
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }#T_26773_row0_col9,#T_26773_row3_col8{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_26773_row0_col10,#T_26773_row3_col11{
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }#T_26773_row0_col11,#T_26773_row2_col4,#T_26773_row7_col1,#T_26773_row7_col4,#T_26773_row10_col0{
#             background-color:  #a8bedc;
#             color:  #000000;
#         }#T_26773_row1_col0,#T_26773_row3_col4,#T_26773_row5_col3{
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }#T_26773_row1_col3,#T_26773_row2_col5{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_26773_row1_col4{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_26773_row1_col5{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_26773_row1_col6{
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }#T_26773_row1_col7{
#             background-color:  #b0c2de;
#             color:  #000000;
#         }#T_26773_row1_col8{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_26773_row1_col10{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_26773_row2_col0{
#             background-color:  #0566a0;
#             color:  #f1f1f1;
#         }#T_26773_row2_col3,#T_26773_row3_col9,#T_26773_row4_col6,#T_26773_row5_col4,#T_26773_row11_col7{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_26773_row2_col6,#T_26773_row7_col8{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_26773_row2_col7{
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }#T_26773_row2_col8,#T_26773_row9_col3,#T_26773_row11_col5{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_26773_row2_col9{
#             background-color:  #86b0d3;
#             color:  #000000;
#         }#T_26773_row2_col10,#T_26773_row6_col1,#T_26773_row7_col3{
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }#T_26773_row2_col11{
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }#T_26773_row3_col0{
#             background-color:  #7eadd1;
#             color:  #000000;
#         }#T_26773_row3_col1{
#             background-color:  #acc0dd;
#             color:  #000000;
#         }#T_26773_row3_col2,#T_26773_row5_col8{
#             background-color:  #89b1d4;
#             color:  #000000;
#         }#T_26773_row3_col5{
#             background-color:  #c1cae2;
#             color:  #000000;
#         }#T_26773_row3_col6,#T_26773_row6_col0{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_26773_row3_col7{
#             background-color:  #529bc7;
#             color:  #000000;
#         }#T_26773_row3_col10{
#             background-color:  #abbfdc;
#             color:  #000000;
#         }#T_26773_row4_col0,#T_26773_row9_col11{
#             background-color:  #83afd3;
#             color:  #000000;
#         }#T_26773_row4_col1{
#             background-color:  #9ebad9;
#             color:  #000000;
#         }#T_26773_row4_col2{
#             background-color:  #79abd0;
#             color:  #000000;
#         }#T_26773_row4_col3{
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }#T_26773_row4_col5{
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }#T_26773_row4_col7{
#             background-color:  #81aed2;
#             color:  #000000;
#         }#T_26773_row4_col8,#T_26773_row5_col9,#T_26773_row6_col4{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_26773_row4_col9,#T_26773_row9_col4,#T_26773_row11_col2{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_26773_row5_col0{
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }#T_26773_row5_col1{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_26773_row5_col2,#T_26773_row5_col7{
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }#T_26773_row5_col6{
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }#T_26773_row5_col10,#T_26773_row9_col8{
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }#T_26773_row5_col11{
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }#T_26773_row6_col2{
#             background-color:  #a5bddb;
#             color:  #000000;
#         }#T_26773_row6_col3{
#             background-color:  #cacee5;
#             color:  #000000;
#         }#T_26773_row6_col5{
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }#T_26773_row6_col7{
#             background-color:  #a4bcda;
#             color:  #000000;
#         }#T_26773_row6_col8{
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }#T_26773_row6_col9,#T_26773_row8_col11{
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }#T_26773_row6_col10,#T_26773_row8_col5{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_26773_row6_col11{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_26773_row7_col0{
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }#T_26773_row7_col2{
#             background-color:  #4697c4;
#             color:  #000000;
#         }#T_26773_row7_col5,#T_26773_row8_col6{
#             background-color:  #eee8f3;
#             color:  #000000;
#         }#T_26773_row7_col6{
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }#T_26773_row7_col9{
#             background-color:  #b7c5df;
#             color:  #000000;
#         }#T_26773_row7_col11{
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }#T_26773_row8_col1{
#             background-color:  #71a8ce;
#             color:  #000000;
#         }#T_26773_row8_col2{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_26773_row8_col7,#T_26773_row11_col1{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_26773_row8_col9{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_26773_row8_col10{
#             background-color:  #80aed2;
#             color:  #000000;
#         }#T_26773_row9_col0{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_26773_row9_col2{
#             background-color:  #589ec8;
#             color:  #000000;
#         }#T_26773_row9_col5{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_26773_row9_col6{

# %%
# Transforms the 'quality' column into boolean where True means good.
df['quality'] = df['quality'] > 5

# Save the target variable into y and the inputs as X.
y = df.pop('quality')
X = df.copy()

# %%
# Train and Test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Normalization of X. Neural Networks tends to learn better with lower numbers.
ss = StandardScaler()
ss.fit(X_train)

# Notice that the Scaler is trained with the training data, but it is applied in either training and test data.
X_train = ss.transform(X_train)
X_test = ss.transform(X_test)

# %% [markdown]
# ## Modeling

# %%
# In this notebook, it will be created a Sequential NN with Dense layers.
# Notice that in the last layer it is used the sigmoid activation function and only one neuron to recieve a probability of beeing Good.
x_dim = X_train.shape[1]

rna = Sequential()
rna.add(layers.Dense(16, activation='relu', input_dim=x_dim))
rna.add(layers.Dense(1, activation='sigmoid'))

rna.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                192
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 209
# Trainable params: 209
# Non-trainable params: 0
# _________________________________________________________________

# %%
# The loss funcion is set to be 'binary_crossentropy' and metrics 'AUC' due to the problem be a binary classification one.
rna.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['AUC'])

history = rna.fit(X_train, y_train, epochs=200, validation_data=(X_test,y_test), verbose=1)
# Out:
# Epoch 1/200
# 40/40 [==============================] - 1s 4ms/step - loss: 0.6438 - auc: 0.6967 - val_loss: 0.6054 - val_auc: 0.7307
# Epoch 2/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.6032 - auc: 0.7488 - val_loss: 0.5777 - val_auc: 0.7613
# Epoch 3/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5783 - auc: 0.7719 - val_loss: 0.5618 - val_auc: 0.7759
# Epoch 4/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5629 - auc: 0.7832 - val_loss: 0.5504 - val_auc: 0.7844
# Epoch 5/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5516 - auc: 0.7919 - val_loss: 0.5421 - val_auc: 0.7910
# Epoch 6/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5441 - auc: 0.7973 - val_loss: 0.5364 - val_auc: 0.7963
# Epoch 7/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5376 - auc: 0.8031 - val_loss: 0.5301 - val_auc: 0.8016
# Epoch 8/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5329 - auc: 0.8069 - val_loss: 0.5270 - val_auc: 0.8028
# Epoch 9/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5285 - auc: 0.8110 - val_loss: 0.5235 - val_auc: 0.8072
# Epoch 10/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5252 - auc: 0.8138 - val_loss: 0.5207 - val_auc: 0.8098
# Epoch 11/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5219 - auc: 0.8167 - val_loss: 0.5178 - val_auc: 0.8120
# Epoch 12/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5194 - auc: 0.8190 - val_loss: 0.5153 - val_auc: 0.8142
# Epoch 13/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5171 - auc: 0.8209 - val_loss: 0.5142 - val_auc: 0.8162
# Epoch 14/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5144 - auc: 0.8232 - val_loss: 0.5100 - val_auc: 0.8189
# Epoch 15/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5126 - auc: 0.8248 - val_loss: 0.5077 - val_auc: 0.8209
# Epoch 16/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5102 - auc: 0.8270 - val_loss: 0.5075 - val_auc: 0.8237
# Epoch 17/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5083 - auc: 0.8285 - val_loss: 0.5049 - val_auc: 0.8258
# Epoch 18/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5066 - auc: 0.8298 - val_loss: 0.5035 - val_auc: 0.8270
# Epoch 19/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5049 - auc: 0.8311 - val_loss: 0.5020 - val_auc: 0.8286
# Epoch 20/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5033 - auc: 0.8325 - val_loss: 0.5016 - val_auc: 0.8278
# Epoch 21/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5020 - auc: 0.8341 - val_loss: 0.5004 - val_auc: 0.8310
# Epoch 22/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5006 - auc: 0.8346 - val_loss: 0.4973 - val_auc: 0.8319
# Epoch 23/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4988 - auc: 0.8362 - val_loss: 0.4952 - val_auc: 0.8349
# Epoch 24/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4976 - auc: 0.8374 - val_loss: 0.4958 - val_auc: 0.8353
# Epoch 25/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4966 - auc: 0.8378 - val_loss: 0.4927 - val_auc: 0.8364
# Epoch 26/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4959 - auc: 0.8384 - val_loss: 0.4903 - val_auc: 0.8381
# Epoch 27/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4937 - auc: 0.8404 - val_loss: 0.4913 - val_auc: 0.8387
# Epoch 28/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4932 - auc: 0.8408 - val_loss: 0.4913 - val_auc: 0.8382
# Epoch 29/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4915 - auc: 0.8421 - val_loss: 0.4899 - val_auc: 0.8391
# Epoch 30/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4908 - auc: 0.8426 - val_loss: 0.4883 - val_auc: 0.8404
# Epoch 31/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4899 - auc: 0.8431 - val_loss: 0.4867 - val_auc: 0.8409
# Epoch 32/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4891 - auc: 0.8437 - val_loss: 0.4858 - val_auc: 0.8421
# Epoch 33/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4883 - auc: 0.8444 - val_loss: 0.4860 - val_auc: 0.8426
# Epoch 34/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4870 - auc: 0.8455 - val_loss: 0.4854 - val_auc: 0.8420
# Epoch 35/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4866 - auc: 0.8458 - val_loss: 0.4841 - val_auc: 0.8427
# Epoch 36/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4856 - auc: 0.8469 - val_loss: 0.4836 - val_auc: 0.8435
# Epoch 37/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4852 - auc: 0.8472 - val_loss: 0.4823 - val_auc: 0.8450
# Epoch 38/200
# 40/40 [==============================] - 0s 930us/step - loss: 0.4839 - auc: 0.8480 - val_loss: 0.4836 - val_auc: 0.8434
# Epoch 39/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4834 - auc: 0.8485 - val_loss: 0.4812 - val_auc: 0.8448
# Epoch 40/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4828 - auc: 0.8488 - val_loss: 0.4814 - val_auc: 0.8444
# Epoch 41/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4824 - auc: 0.8489 - val_loss: 0.4795 - val_auc: 0.8469
# Epoch 42/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4815 - auc: 0.8502 - val_loss: 0.4807 - val_auc: 0.8468
# Epoch 43/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4812 - auc: 0.8501 - val_loss: 0.4785 - val_auc: 0.8471
# Epoch 44/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4802 - auc: 0.8509 - val_loss: 0.4790 - val_auc: 0.8474
# Epoch 45/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4795 - auc: 0.8513 - val_loss: 0.4796 - val_auc: 0.8469
# Epoch 46/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4794 - auc: 0.8514 - val_loss: 0.4780 - val_auc: 0.8496
# Epoch 47/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4782 - auc: 0.8523 - val_loss: 0.4784 - val_auc: 0.8479
# Epoch 48/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4780 - auc: 0.8523 - val_loss: 0.4778 - val_auc: 0.8495
# Epoch 49/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4774 - auc: 0.8532 - val_loss: 0.4782 - val_auc: 0.8505
# Epoch 50/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4770 - auc: 0.8532 - val_loss: 0.4766 - val_auc: 0.8502
# Epoch 51/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4766 - auc: 0.8536 - val_loss: 0.4761 - val_auc: 0.8499
# Epoch 52/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4765 - auc: 0.8534 - val_loss: 0.4772 - val_auc: 0.8503
# Epoch 53/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4761 - auc: 0.8538 - val_loss: 0.4774 - val_auc: 0.8514
# Epoch 54/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4761 - auc: 0.8539 - val_loss: 0.4755 - val_auc: 0.8521
# Epoch 55/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4751 - auc: 0.8547 - val_loss: 0.4754 - val_auc: 0.8516
# Epoch 56/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4750 - auc: 0.8545 - val_loss: 0.4735 - val_auc: 0.8521
# Epoch 57/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4748 - auc: 0.8548 - val_loss: 0.4756 - val_auc: 0.8522
# Epoch 58/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4749 - auc: 0.8546 - val_loss: 0.4754 - val_auc: 0.8522
# Epoch 59/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4739 - auc: 0.8554 - val_loss: 0.4754 - val_auc: 0.8521
# Epoch 60/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4742 - auc: 0.8549 - val_loss: 0.4741 - val_auc: 0.8521
# Epoch 61/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4732 - auc: 0.8558 - val_loss: 0.4747 - val_auc: 0.8524
# Epoch 62/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4725 - auc: 0.8562 - val_loss: 0.4742 - val_auc: 0.8525
# Epoch 63/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4730 - auc: 0.8559 - val_loss: 0.4740 - val_auc: 0.8530
# Epoch 64/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4721 - auc: 0.8567 - val_loss: 0.4738 - val_auc: 0.8539
# Epoch 65/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4722 - auc: 0.8567 - val_loss: 0.4740 - val_auc: 0.8536
# Epoch 66/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4717 - auc: 0.8569 - val_loss: 0.4728 - val_auc: 0.8532
# Epoch 67/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4715 - auc: 0.8567 - val_loss: 0.4734 - val_auc: 0.8540
# Epoch 68/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4711 - auc: 0.8573 - val_loss: 0.4748 - val_auc: 0.8530
# Epoch 69/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4717 - auc: 0.8567 - val_loss: 0.4726 - val_auc: 0.8544
# Epoch 70/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4707 - auc: 0.8575 - val_loss: 0.4719 - val_auc: 0.8538
# Epoch 71/200
# 40/40 [==============================] - 0s 890us/step - loss: 0.4703 - auc: 0.8577 - val_loss: 0.4740 - val_auc: 0.8540
# Epoch 72/200
# 40/40 [==============================] - 0s 769us/step - loss: 0.4696 - auc: 0.8583 - val_loss: 0.4724 - val_auc: 0.8541
# Epoch 73/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4701 - auc: 0.8577 - val_loss: 0.4728 - val_auc: 0.8540
# Epoch 74/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4698 - auc: 0.8578 - val_loss: 0.4733 - val_auc: 0.8538
# Epoch 75/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4696 - auc: 0.8580 - val_loss: 0.4733 - val_auc: 0.8535
# Epoch 76/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4692 - auc: 0.8584 - val_loss: 0.4727 - val_auc: 0.8554
# Epoch 77/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4686 - auc: 0.8590 - val_loss: 0.4735 - val_auc: 0.8543
# Epoch 78/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4687 - auc: 0.8589 - val_loss: 0.4712 - val_auc: 0.8550
# Epoch 79/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4691 - auc: 0.8584 - val_loss: 0.4717 - val_auc: 0.8552
# Epoch 80/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4683 - auc: 0.8589 - val_loss: 0.4712 - val_auc: 0.8552
# Epoch 81/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4675 - auc: 0.8593 - val_loss: 0.4712 - val_auc: 0.8552
# Epoch 82/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4677 - auc: 0.8593 - val_loss: 0.4710 - val_auc: 0.8550
# Epoch 83/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4670 - auc: 0.8600 - val_loss: 0.4723 - val_auc: 0.8547
# Epoch 84/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4666 - auc: 0.8601 - val_loss: 0.4721 - val_auc: 0.8548
# Epoch 85/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4665 - auc: 0.8602 - val_loss: 0.4707 - val_auc: 0.8556
# Epoch 86/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4666 - auc: 0.8601 - val_loss: 0.4694 - val_auc: 0.8561
# Epoch 87/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4658 - auc: 0.8607 - val_loss: 0.4710 - val_auc: 0.8550
# Epoch 88/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4664 - auc: 0.8601 - val_loss: 0.4701 - val_auc: 0.8562
# Epoch 89/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4656 - auc: 0.8610 - val_loss: 0.4708 - val_auc: 0.8558
# Epoch 90/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4655 - auc: 0.8609 - val_loss: 0.4681 - val_auc: 0.8563
# Epoch 91/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4644 - auc: 0.8615 - val_loss: 0.4711 - val_auc: 0.8550
# Epoch 92/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4652 - auc: 0.8609 - val_loss: 0.4714 - val_auc: 0.8546
# Epoch 93/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4648 - auc: 0.8615 - val_loss: 0.4700 - val_auc: 0.8554
# Epoch 94/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4639 - auc: 0.8618 - val_loss: 0.4696 - val_auc: 0.8551
# Epoch 95/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4653 - auc: 0.8609 - val_loss: 0.4692 - val_auc: 0.8556
# Epoch 96/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4644 - auc: 0.8614 - val_loss: 0.4695 - val_auc: 0.8560
# Epoch 97/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4637 - auc: 0.8622 - val_loss: 0.4695 - val_auc: 0.8555
# Epoch 98/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4630 - auc: 0.8625 - val_loss: 0.4694 - val_auc: 0.8562
# Epoch 99/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4635 - auc: 0.8624 - val_loss: 0.4705 - val_auc: 0.8554
# Epoch 100/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4629 - auc: 0.8626 - val_loss: 0.4691 - val_auc: 0.8554
# Epoch 101/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4623 - auc: 0.8630 - val_loss: 0.4693 - val_auc: 0.8556
# Epoch 102/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4623 - auc: 0.8632 - val_loss: 0.4706 - val_auc: 0.8553
# Epoch 103/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4624 - auc: 0.8628 - val_loss: 0.4684 - val_auc: 0.8559
# Epoch 104/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4617 - auc: 0.8632 - val_loss: 0.4708 - val_auc: 0.8554
# Epoch 105/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4615 - auc: 0.8636 - val_loss: 0.4700 - val_auc: 0.8553
# Epoch 106/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4617 - auc: 0.8632 - val_loss: 0.4678 - val_auc: 0.8563
# Epoch 107/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4609 - auc: 0.8641 - val_loss: 0.4707 - val_auc: 0.8552
# Epoch 108/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4612 - auc: 0.8639 - val_loss: 0.4701 - val_auc: 0.8551
# Epoch 109/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4609 - auc: 0.8641 - val_loss: 0.4701 - val_auc: 0.8559
# Epoch 110/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4607 - auc: 0.8641 - val_loss: 0.4693 - val_auc: 0.8563
# Epoch 111/200
# 40/40 [==============================] - 0s 985us/step - loss: 0.4604 - auc: 0.8643 - val_loss: 0.4689 - val_auc: 0.8555
# Epoch 112/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4603 - auc: 0.8642 - val_loss: 0.4697 - val_auc: 0.8556
# Epoch 113/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4606 - auc: 0.8642 - val_loss: 0.4680 - val_auc: 0.8561
# Epoch 114/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4598 - auc: 0.8644 - val_loss: 0.4708 - val_auc: 0.8562
# Epoch 115/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4598 - auc: 0.8648 - val_loss: 0.4694 - val_auc: 0.8556
# Epoch 116/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4593 - auc: 0.8653 - val_loss: 0.4690 - val_auc: 0.8556
# Epoch 117/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4593 - auc: 0.8651 - val_loss: 0.4692 - val_auc: 0.8553
# Epoch 118/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4587 - auc: 0.8655 - val_loss: 0.4693 - val_auc: 0.8563
# Epoch 119/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4591 - auc: 0.8647 - val_loss: 0.4677 - val_auc: 0.8574
# Epoch 120/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4589 - auc: 0.8655 - val_loss: 0.4696 - val_auc: 0.8554
# Epoch 121/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4589 - auc: 0.8651 - val_loss: 0.4702 - val_auc: 0.8551
# Epoch 122/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4584 - auc: 0.8656 - val_loss: 0.4686 - val_auc: 0.8560
# Epoch 123/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4588 - auc: 0.8655 - val_loss: 0.4697 - val_auc: 0.8552
# Epoch 124/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4582 - auc: 0.8661 - val_loss: 0.4695 - val_auc: 0.8558
# Epoch 125/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4581 - auc: 0.8659 - val_loss: 0.4691 - val_auc: 0.8550
# Epoch 126/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4578 - auc: 0.8663 - val_loss: 0.4707 - val_auc: 0.8554
# Epoch 127/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4575 - auc: 0.8661 - val_loss: 0.4688 - val_auc: 0.8555
# Epoch 128/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4575 - auc: 0.8663 - val_loss: 0.4704 - val_auc: 0.8555
# Epoch 129/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4573 - auc: 0.8666 - val_loss: 0.4696 - val_auc: 0.8541
# Epoch 130/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4570 - auc: 0.8665 - val_loss: 0.4700 - val_auc: 0.8551
# Epoch 131/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4564 - auc: 0.8671 - val_loss: 0.4686 - val_auc: 0.8564
# Epoch 132/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4567 - auc: 0.8671 - val_loss: 0.4690 - val_auc: 0.8561
# Epoch 133/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4563 - auc: 0.8673 - val_loss: 0.4689 - val_auc: 0.8560
# Epoch 134/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4566 - auc: 0.8670 - val_loss: 0.4699 - val_auc: 0.8549
# Epoch 135/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4567 - auc: 0.8669 - val_loss: 0.4695 - val_auc: 0.8558
# Epoch 136/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4566 - auc: 0.8669 - val_loss: 0.4706 - val_auc: 0.8547
# Epoch 137/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4557 - auc: 0.8677 - val_loss: 0.4699 - val_auc: 0.8552
# Epoch 138/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4556 - auc: 0.8675 - val_loss: 0.4716 - val_auc: 0.8542
# Epoch 139/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4557 - auc: 0.8678 - val_loss: 0.4677 - val_auc: 0.8563
# Epoch 140/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4560 - auc: 0.8676 - val_loss: 0.4697 - val_auc: 0.8552
# Epoch 141/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4552 - auc: 0.8676 - val_loss: 0.4698 - val_auc: 0.8548
# Epoch 142/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4555 - auc: 0.8677 - val_loss: 0.4719 - val_auc: 0.8535
# Epoch 143/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4546 - auc: 0.8681 - val_loss: 0.4676 - val_auc: 0.8555
# Epoch 144/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4542 - auc: 0.8686 - val_loss: 0.4700 - val_auc: 0.8543
# Epoch 145/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4540 - auc: 0.8687 - val_loss: 0.4689 - val_auc: 0.8554
# Epoch 146/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4542 - auc: 0.8684 - val_loss: 0.4684 - val_auc: 0.8545
# Epoch 147/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4548 - auc: 0.8684 - val_loss: 0.4723 - val_auc: 0.8542
# Epoch 148/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4538 - auc: 0.8691 - val_loss: 0.4690 - val_auc: 0.8542
# Epoch 149/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4538 - auc: 0.8691 - val_loss: 0.4711 - val_auc: 0.8540
# Epoch 150/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4531 - auc: 0.8694 - val_loss: 0.4699 - val_auc: 0.8552
# Epoch 151/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4531 - auc: 0.8694 - val_loss: 0.4697 - val_auc: 0.8540
# Epoch 152/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4533 - auc: 0.8693 - val_loss: 0.4692 - val_auc: 0.8551
# Epoch 153/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4527 - auc: 0.8697 - val_loss: 0.4712 - val_auc: 0.8539
# Epoch 154/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4524 - auc: 0.8701 - val_loss: 0.4681 - val_auc: 0.8547
# Epoch 155/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4525 - auc: 0.8698 - val_loss: 0.4705 - val_auc: 0.8543
# Epoch 156/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4524 - auc: 0.8701 - val_loss: 0.4698 - val_auc: 0.8547
# Epoch 157/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4521 - auc: 0.8700 - val_loss: 0.4692 - val_auc: 0.8547
# Epoch 158/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4522 - auc: 0.8701 - val_loss: 0.4685 - val_auc: 0.8548
# Epoch 159/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4516 - auc: 0.8705 - val_loss: 0.4702 - val_auc: 0.8536
# Epoch 160/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4519 - auc: 0.8702 - val_loss: 0.4698 - val_auc: 0.8541
# Epoch 161/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4513 - auc: 0.8708 - val_loss: 0.4695 - val_auc: 0.8551
# Epoch 162/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4515 - auc: 0.8704 - val_loss: 0.4687 - val_auc: 0.8549
# Epoch 163/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4515 - auc: 0.8707 - val_loss: 0.4683 - val_auc: 0.8552
# Epoch 164/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4507 - auc: 0.8712 - val_loss: 0.4716 - val_auc: 0.8542
# Epoch 165/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4515 - auc: 0.8703 - val_loss: 0.4700 - val_auc: 0.8551
# Epoch 166/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4515 - auc: 0.8705 - val_loss: 0.4707 - val_auc: 0.8537
# Epoch 167/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4510 - auc: 0.8708 - val_loss: 0.4684 - val_auc: 0.8550
# Epoch 168/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4505 - auc: 0.8712 - val_loss: 0.4699 - val_auc: 0.8543
# Epoch 169/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4510 - auc: 0.8708 - val_loss: 0.4697 - val_auc: 0.8545
# Epoch 170/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4508 - auc: 0.8710 - val_loss: 0.4692 - val_auc: 0.8551
# Epoch 171/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4506 - auc: 0.8713 - val_loss: 0.4696 - val_auc: 0.8547
# Epoch 172/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4500 - auc: 0.8712 - val_loss: 0.4697 - val_auc: 0.8549
# Epoch 173/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4497 - auc: 0.8717 - val_loss: 0.4700 - val_auc: 0.8542
# Epoch 174/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4505 - auc: 0.8713 - val_loss: 0.4687 - val_auc: 0.8543
# Epoch 175/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4494 - auc: 0.8716 - val_loss: 0.4705 - val_auc: 0.8535
# Epoch 176/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4497 - auc: 0.8716 - val_loss: 0.4682 - val_auc: 0.8552
# Epoch 177/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4499 - auc: 0.8716 - val_loss: 0.4717 - val_auc: 0.8542
# Epoch 178/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4502 - auc: 0.8712 - val_loss: 0.4709 - val_auc: 0.8536
# Epoch 179/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4494 - auc: 0.8715 - val_loss: 0.4708 - val_auc: 0.8548
# Epoch 180/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4503 - auc: 0.8713 - val_loss: 0.4701 - val_auc: 0.8551
# Epoch 181/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4490 - auc: 0.8720 - val_loss: 0.4695 - val_auc: 0.8549
# Epoch 182/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4487 - auc: 0.8725 - val_loss: 0.4679 - val_auc: 0.8553
# Epoch 183/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4486 - auc: 0.8724 - val_loss: 0.4701 - val_auc: 0.8540
# Epoch 184/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4488 - auc: 0.8721 - val_loss: 0.4704 - val_auc: 0.8551
# Epoch 185/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4480 - auc: 0.8726 - val_loss: 0.4699 - val_auc: 0.8551
# Epoch 186/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4487 - auc: 0.8723 - val_loss: 0.4698 - val_auc: 0.8551
# Epoch 187/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4484 - auc: 0.8724 - val_loss: 0.4705 - val_auc: 0.8545
# Epoch 188/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4487 - auc: 0.8725 - val_loss: 0.4695 - val_auc: 0.8545
# Epoch 189/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4480 - auc: 0.8729 - val_loss: 0.4701 - val_auc: 0.8543
# Epoch 190/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4483 - auc: 0.8722 - val_loss: 0.4689 - val_auc: 0.8547
# Epoch 191/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4481 - auc: 0.8726 - val_loss: 0.4693 - val_auc: 0.8546
# Epoch 192/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4480 - auc: 0.8727 - val_loss: 0.4691 - val_auc: 0.8548
# Epoch 193/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4481 - auc: 0.8728 - val_loss: 0.4703 - val_auc: 0.8544
# Epoch 194/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4475 - auc: 0.8732 - val_loss: 0.4681 - val_auc: 0.8556
# Epoch 195/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4475 - auc: 0.8729 - val_loss: 0.4715 - val_auc: 0.8535
# Epoch 196/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.4470 - auc: 0.8734 - val_loss: 0.4700 - val_auc: 0.8546
# Epoch 197/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4474 - auc: 0.8734 - val_loss: 0.4681 - val_auc: 0.8543
# Epoch 198/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4476 - auc: 0.8731 - val_loss: 0.4707 - val_auc: 0.8549
# Epoch 199/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4467 - auc: 0.8736 - val_loss: 0.4668 - val_auc: 0.8561
# Epoch 200/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4472 - auc: 0.8730 - val_loss: 0.4708 - val_auc: 0.8539

# %% [markdown]
# ## Evaluation

# %%
# Retrive the training historic
history_dict = history.history

# Transform the Loss and the Accuracy into vectors.
loss = history_dict['loss']
acc = history_dict['auc']
val_loss = history_dict['val_loss']
val_acc = history_dict['val_auc']

# Create an epoch vector.
epochs = range(1, len(loss) + 1)

# Loss Function x Epochs
plt.plot(epochs, loss, 'b', label='Train data')
plt.plot(epochs, val_loss, 'r', label='Test data')
plt.title('Loss function value')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Accuracy x Epochs
plt.plot(epochs, acc, 'b', label='Train data')
plt.plot(epochs, val_acc, 'r', label='Test data')
plt.title('Accuracy value')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
c_train = rna.evaluate(X_train, y_train)
c_test = rna.evaluate(X_test, y_test)
# Out:
# 40/40 [==============================] - 0s 784us/step - loss: 0.4446 - auc: 0.8750
# 10/10 [==============================] - 0s 953us/step - loss: 0.4708 - auc: 0.8539

# %%
# Make the predictions from the test data and round them since they are a percentage. If it is higher than 0.5, it is 1.
y_prev = rna.predict(X_test)
classes = np.round(y_prev)

# Real Classification x Model Predictions
plt.figure(figsize=(16, 4))
plt.plot(y_test.reset_index(drop=True), 'ro', label='Real Classification')
plt.plot(classes, 'bo', label="Model's Prediction")
plt.title('Real Classification x Model Predictions')
plt.xlabel('Exemples')
plt.ylabel('Classification')
plt.legend()
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# On a binary classificator, a random generator accuracy is 0.5 since the data has two outcomes.
#
# This Basic Neural Network model was able to achive an accuracy of 0.8539 for the test data using only 1 dense layer and 1 output layer.
#
# As we can see on the **Evaluation section**, the train data loss function was minimized along the test data without neither overfitting or underfitting.
#
# The 'Classification x Model Predictions' plot shows a predominance of right prediction (blue dots) and few wrong ones (red dots).
#
# A better result could be achived with a few improviments such as:
# - Higher database (*only 1599 examples used*);
# - Different hyperparameters on the network setup;
# - Better Data Preparation techniques;
